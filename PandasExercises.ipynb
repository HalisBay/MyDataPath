# %%
import pandas as pd
import numpy as np

# %%
g20Country = pd.Series( [1400, 1300, 330, 275, 213, 225, 220, 170, 145, 130, 126, 115, 120, 110, 100, 83, 85, 85, 70])

# %%
g20Country
# Out:
# 0     1400
# 1     1300
# 2      330
# 3      275
# 4      213
# 5      225
# 6      220
# 7      170
# 8      145
# 9      130
# 10     126
# 11     115
# 12     120
# 13     110
# 14     100
# 15      83
# 16      85
# 17      85
# 18      70
# dtype: int64

# %%
g20Country.name = "G20 Population in millions"

# %%
g20Country
# Out:
# 0     1400
# 1     1300
# 2      330
# 3      275
# 4      213
# 5      225
# 6      220
# 7      170
# 8      145
# 9      130
# 10     126
# 11     115
# 12     120
# 13     110
# 14     100
# 15      83
# 16      85
# 17      85
# 18      70
# Name: G20 Population in millions, dtype: int64

# %%
g20Country.values
# Out:
# array([1400, 1300,  330,  275,  213,  225,  220,  170,  145,  130,  126,
#         115,  120,  110,  100,   83,   85,   85,   70])

# %%
type(g20Country.values)
# Out:
# numpy.ndarray

# %%
g20Country[17]
# Out:
# 85

# %%
g20Country.index
# Out:
# RangeIndex(start=0, stop=19, step=1)

# %%
g20Country.index = [
   'China', 'India', 'United States', 'Indonesia', 'Pakistan',
    'Brazil', 'Nigeria', 'Bangladesh', 'Russia', 'Mexico', 'Japan',
    'Philippines', 'Ethiopia', 'Egypt', 'Vietnam', 'Germany', 'Turkey',
    'Iran', 'Thailand'
]
g20Country
# Out:
# China            1400
# India            1300
# United States     330
# Indonesia         275
# Pakistan          213
# Brazil            225
# Nigeria           220
# Bangladesh        170
# Russia            145
# Mexico            130
# Japan             126
# Philippines       115
# Ethiopia          120
# Egypt             110
# Vietnam           100
# Germany            83
# Turkey             85
# Iran               85
# Thailand           70
# Name: G20 Population in millions, dtype: int64

# %%
pd.Series({
    'China': 1400,
    'India': 1300,
    'United States': 330,
    'Indonesia': 275,
    'Pakistan': 213,
    'Brazil': 225,
    'Nigeria': 220,
    'Bangladesh': 170,
    'Russia': 145,
    'Mexico': 130,
    'Japan': 126,
    'Philippines': 115,
    'Ethiopia': 120,
    'Egypt': 110,
    'Vietnam': 100,
    'Germany': 83,
    'Turkey': 85,
    'Iran': 85,
    'Thailand': 70
}, name='G20 Population in millions')
# Out:
# China            1400
# India            1300
# United States     330
# Indonesia         275
# Pakistan          213
# Brazil            225
# Nigeria           220
# Bangladesh        170
# Russia            145
# Mexico            130
# Japan             126
# Philippines       115
# Ethiopia          120
# Egypt             110
# Vietnam           100
# Germany            83
# Turkey             85
# Iran               85
# Thailand           70
# Name: G20 Population in millions, dtype: int64

# %%
g20Country[['Turkey','Japan']]
# Out:
# Turkey     85
# Japan     126
# Name: G20 Population in millions, dtype: int64

# %%
g20Country.iloc[[0,7]]
# Out:
# China         1400
# Bangladesh     170
# Name: G20 Population in millions, dtype: int64

# %%
g20Country['Japan' : 'Turkey']
# Out:
# Japan          126
# Philippines    115
# Ethiopia       120
# Egypt          110
# Vietnam        100
# Germany         83
# Turkey          85
# Name: G20 Population in millions, dtype: int64

# %%
g20Country.iloc[3:7]
# Out:
# Indonesia    275
# Pakistan     213
# Brazil       225
# Nigeria      220
# Name: G20 Population in millions, dtype: int64

# %%
g20Country >= 85
# Out:
# China             True
# India             True
# United States     True
# Indonesia         True
# Pakistan          True
# Brazil            True
# Nigeria           True
# Bangladesh        True
# Russia            True
# Mexico            True
# Japan             True
# Philippines       True
# Ethiopia          True
# Egypt             True
# Vietnam           True
# Germany          False
# Turkey            True
# Iran              True
# Thailand         False
# Name: G20 Population in millions, dtype: bool

# %%
g20Country[g20Country >=85]
# Out:
# China            1400
# India            1300
# United States     330
# Indonesia         275
# Pakistan          213
# Brazil            225
# Nigeria           220
# Bangladesh        170
# Russia            145
# Mexico            130
# Japan             126
# Philippines       115
# Ethiopia          120
# Egypt             110
# Vietnam           100
# Turkey             85
# Iran               85
# Name: G20 Population in millions, dtype: int64

# %%
g20Country.mean()
# Out:
# 279.05263157894734

# %%
g20Country[g20Country > g20Country.mean()]
# Out:
# China            1400
# India            1300
# United States     330
# Name: G20 Population in millions, dtype: int64

# %%
g20Country.std()
# Out:
# 384.2776012907871

# %%
g20Country[(g20Country > g20Country.mean() - g20Country.std() / 2) | (g20Country > g20Country.mean() + g20Country.std() / 2)]
# Out:
# China            1400
# India            1300
# United States     330
# Indonesia         275
# Pakistan          213
# Brazil            225
# Nigeria           220
# Bangladesh        170
# Russia            145
# Mexico            130
# Japan             126
# Philippines       115
# Ethiopia          120
# Egypt             110
# Vietnam           100
# Name: G20 Population in millions, dtype: int64

# %%
g20Country * 1000000
# Out:
# China            1400000000
# India            1300000000
# United States     330000000
# Indonesia         275000000
# Pakistan          213000000
# Brazil            225000000
# Nigeria           220000000
# Bangladesh        170000000
# Russia            145000000
# Mexico            130000000
# Japan             126000000
# Philippines       115000000
# Ethiopia          120000000
# Egypt             110000000
# Vietnam           100000000
# Germany            83000000
# Turkey             85000000
# Iran               85000000
# Thailand           70000000
# Name: G20 Population in millions, dtype: int64

# %%
g20Country[(g20Country >= 85) & (g20Country <= 215)]
# Out:
# Pakistan       213
# Bangladesh     170
# Russia         145
# Mexico         130
# Japan          126
# Philippines    115
# Ethiopia       120
# Egypt          110
# Vietnam        100
# Turkey          85
# Iran            85
# Name: G20 Population in millions, dtype: int64

# %%
g20Country["Turkey"] = 87.5

# %%
g20Country
# Out:
# China            1400.0
# India            1300.0
# United States     330.0
# Indonesia         275.0
# Pakistan          213.0
# Brazil            225.0
# Nigeria           220.0
# Bangladesh        170.0
# Russia            145.0
# Mexico            130.0
# Japan             126.0
# Philippines       115.0
# Ethiopia          120.0
# Egypt             110.0
# Vietnam           100.0
# Germany            83.0
# Turkey             87.5
# Iran               85.0
# Thailand           70.0
# Name: G20 Population in millions, dtype: float64

# %%
x = pd.Series([3,1,2])
indexNames = [ 'three','one', 'two']

x.index = indexNames
x
# Out:
# three    3
# one      1
# two      2
# dtype: int64

# %%
x.sort_values()
# Out:
# one      1
# two      2
# three    3
# dtype: int64

# %%
df = pd.DataFrame({
    'Population': [35.467, 63.951, 80.94 , 60.665, 127.061, 64.511, 318.523],
    'GDP': [
        1785387,
        2833687,
        3874437,
        2167744,
        4602367,
        2950039,
        17348075
    ],
    'Surface Area': [
        9984670,
        640679,
        357114,
        301336,
        377930,
        242495,
        9525067
    ],
    'HDI': [
        0.913,
        0.888,
        0.916,
        0.873,
        0.891,
        0.907,
        0.915
    ],
    'Continent': [
        'America',
        'Europe',
        'Europe',
        'Europe',
        'Asia',
        'Europe',
        'America'
    ]
}, columns=['Population', 'GDP', 'Surface Area', 'HDI', 'Continent'])

df
# Out:
#    Population       GDP  Surface Area    HDI Continent
# 0      35.467   1785387       9984670  0.913   America
# 1      63.951   2833687        640679  0.888    Europe
# 2      80.940   3874437        357114  0.916    Europe
# 3      60.665   2167744        301336  0.873    Europe
# 4     127.061   4602367        377930  0.891      Asia
# 5      64.511   2950039        242495  0.907    Europe
# 6     318.523  17348075       9525067  0.915   America

# %%
df.index = [
    'Canada',
    'France',
    'Germany',
    'Italy',
    'Japan',
    'United Kingdom',
    'United States',
]
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.columns
# Out:
# Index(['Population', 'GDP', 'Surface Area', 'HDI', 'Continent'], dtype='object')

# %%
df.index
# Out:
# Index(['Canada', 'France', 'Germany', 'Italy', 'Japan', 'United Kingdom',
#        'United States'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, Canada to United States
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Population    7 non-null      float64
#  1   GDP           7 non-null      int64
#  2   Surface Area  7 non-null      int64
#  3   HDI           7 non-null      float64
#  4   Continent     7 non-null      object
# dtypes: float64(2), int64(2), object(1)
# memory usage: 636.0+ bytes

# %%
print("size = ",df.size, "shape = ",
df.shape)
# Out:
# size =  35 shape =  (7, 5)

# %%
df.describe()
# Out:
#        Population           GDP  Surface Area       HDI
# count    7.000000  7.000000e+00  7.000000e+00  7.000000
# mean   107.302571  5.080248e+06  3.061327e+06  0.900429
# std     97.249970  5.494020e+06  4.576187e+06  0.016592
# min     35.467000  1.785387e+06  2.424950e+05  0.873000
# 25%     62.308000  2.500716e+06  3.292250e+05  0.889500
# 50%     64.511000  2.950039e+06  3.779300e+05  0.907000
# 75%    104.000500  4.238402e+06  5.082873e+06  0.914000
# max    318.523000  1.734808e+07  9.984670e+06  0.916000

# %%
df.loc["Canada"]
# Out:
# Population       35.467
# GDP             1785387
# Surface Area    9984670
# HDI               0.913
# Continent       America
# Name: Canada, dtype: object

# %%
df['Population']
# Out:
# Canada             35.467
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United States     318.523
# Name: Population, dtype: float64

# %%
df['Population'].to_frame()
# Out:
#                 Population
# Canada              35.467
# France              63.951
# Germany             80.940
# Italy               60.665
# Japan              127.061
# United Kingdom      64.511
# United States      318.523

# %%
df[['Population', 'GDP']].to_json()
# Out:
# '{"Population":{"Canada":35.467,"France":63.951,"Germany":80.94,"Italy":60.665,"Japan":127.061,"United Kingdom":64.511,"United States":318.523},"GDP":{"Canada":1785387,"France":2833687,"Germany":3874437,"Italy":2167744,"Japan":4602367,"United Kingdom":2950039,"United States":17348075}}'

# %%
df[1:3]
# Out:
#          Population      GDP  Surface Area    HDI Continent
# France       63.951  2833687        640679  0.888    Europe
# Germany      80.940  3874437        357114  0.916    Europe

# %%
df.loc['France': 'Italy']
# Out:
#          Population      GDP  Surface Area    HDI Continent
# France       63.951  2833687        640679  0.888    Europe
# Germany      80.940  3874437        357114  0.916    Europe
# Italy        60.665  2167744        301336  0.873    Europe

# %%
df.loc['France': 'Italy', 'Population']
# Out:
# France     63.951
# Germany    80.940
# Italy      60.665
# Name: Population, dtype: float64

# %%
df.loc[df['Population'] > 70]
# Out:
#                Population       GDP  Surface Area    HDI Continent
# Germany            80.940   3874437        357114  0.916    Europe
# Japan             127.061   4602367        377930  0.891      Asia
# United States     318.523  17348075       9525067  0.915   America

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.drop(['Canada', 'Japan'])
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.drop(columns=['GDP', 'HDI'])
# Out:
#                 Population  Surface Area Continent
# Canada              35.467       9984670   America
# France              63.951        640679    Europe
# Germany             80.940        357114    Europe
# Italy               60.665        301336    Europe
# Japan              127.061        377930      Asia
# United Kingdom      64.511        242495    Europe
# United States      318.523       9525067   America

# %%
df[['Population', 'GDP']] * 1000000
# Out:
#                  Population             GDP
# Canada           35467000.0   1785387000000
# France           63951000.0   2833687000000
# Germany          80940000.0   3874437000000
# Italy            60665000.0   2167744000000
# Japan           127061000.0   4602367000000
# United Kingdom   64511000.0   2950039000000
# United States   318523000.0  17348075000000

# %%
langs = pd.Series(
    ['French', 'German', 'Italian'],
    index=['France', 'Germany', 'Italy'],
    name='Language'
)
langs
# Out:
# France      French
# Germany     German
# Italy      Italian
# Name: Language, dtype: object

# %%
df['Language'] = langs

# %%
df.fillna("somethings")
# Out:
#                 Population       GDP  Surface Area    HDI Continent  \
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America
#
#                   Language
# Canada          somethings
# France              French
# Germany             German
# Italy              Italian
# Japan           somethings
# United Kingdom  somethings
# United States   somethings

# %%
df.reset_index()
# Out:
#             index  Population       GDP  Surface Area    HDI Continent
# 0          Canada      35.467   1785387       9984670  0.913   America
# 1          France      63.951   2833687        640679  0.888    Europe
# 2         Germany      80.940   3874437        357114  0.916    Europe
# 3           Italy      60.665   2167744        301336  0.873    Europe
# 4           Japan     127.061   4602367        377930  0.891      Asia
# 5  United Kingdom      64.511   2950039        242495  0.907    Europe
# 6   United States     318.523  17348075       9525067  0.915   America

# %%
df.set_index('Population')
# Out:
#                  GDP  Surface Area    HDI Continent
# Population
# 35.467       1785387       9984670  0.913   America
# 63.951       2833687        640679  0.888    Europe
# 80.940       3874437        357114  0.916    Europe
# 60.665       2167744        301336  0.873    Europe
# 127.061      4602367        377930  0.891      Asia
# 64.511       2950039        242495  0.907    Europe
# 318.523     17348075       9525067  0.915   America

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
marvel_data = [
    ['Spider-Man', 'male', 1962],
    ['Captain America', 'male', 1941],
    ['Wolverine', 'male', 1974],
    ['Iron Man', 'male', 1963],
    ['Thor', 'male', 1963],
    ['Thing', 'male', 1961],
    ['Mister Fantastic', 'male', 1961],
    ['Hulk', 'male', 1962],
    ['Beast', 'male', 1963],
    ['Invisible Woman', 'female', 1961],
    ['Storm', 'female', 1975],
    ['Namor', 'male', 1939],
    ['Hawkeye', 'male', 1964],
    ['Daredevil', 'male', 1964],
    ['Doctor Strange', 'male', 1963],
    ['Hank Pym', 'male', 1962],
    ['Scarlet Witch', 'female', 1964],
    ['Wasp', 'female', 1963],
    ['Black Widow', 'female', 1964],
    ['Vision', 'male', 1968]
]

marvel_df = pd.DataFrame(data=marvel_data)

marvel_df
# Out:
#                    0       1     2
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968

# %%
col_names = ['name', 'gender', 'first_appearance']

marvel_df.columns = col_names
marvel_df
# Out:
#                 name  gender  first_appearance
# 0         Spider-Man    male              1962
# 1    Captain America    male              1941
# 2          Wolverine    male              1974
# 3           Iron Man    male              1963
# 4               Thor    male              1963
# 5              Thing    male              1961
# 6   Mister Fantastic    male              1961
# 7               Hulk    male              1962
# 8              Beast    male              1963
# 9    Invisible Woman  female              1961
# 10             Storm  female              1975
# 11             Namor    male              1939
# 12           Hawkeye    male              1964
# 13         Daredevil    male              1964
# 14    Doctor Strange    male              1963
# 15          Hank Pym    male              1962
# 16     Scarlet Witch  female              1964
# 17              Wasp  female              1963
# 18       Black Widow  female              1964
# ...

# %%
marvel_df.drop(['name'], axis=1)
marvel_df
# Out:
#                 name  gender  first_appearance
# 0         Spider-Man    male              1962
# 1    Captain America    male              1941
# 2          Wolverine    male              1974
# 3           Iron Man    male              1963
# 4               Thor    male              1963
# 5              Thing    male              1961
# 6   Mister Fantastic    male              1961
# 7               Hulk    male              1962
# 8              Beast    male              1963
# 9    Invisible Woman  female              1961
# 10             Storm  female              1975
# 11             Namor    male              1939
# 12           Hawkeye    male              1964
# 13         Daredevil    male              1964
# 14    Doctor Strange    male              1963
# 15          Hank Pym    male              1962
# 16     Scarlet Witch  female              1964
# 17              Wasp  female              1963
# 18       Black Widow  female              1964
# ...

# %%
marvel_df
# Out:
#                 name  gender  first_appearance
# 0         Spider-Man    male              1962
# 1    Captain America    male              1941
# 2          Wolverine    male              1974
# 3           Iron Man    male              1963
# 4               Thor    male              1963
# 5              Thing    male              1961
# 6   Mister Fantastic    male              1961
# 7               Hulk    male              1962
# 8              Beast    male              1963
# 9    Invisible Woman  female              1961
# 10             Storm  female              1975
# 11             Namor    male              1939
# 12           Hawkeye    male              1964
# 13         Daredevil    male              1964
# 14    Doctor Strange    male              1963
# 15          Hank Pym    male              1962
# 16     Scarlet Witch  female              1964
# 17              Wasp  female              1963
# 18       Black Widow  female              1964
# ...

# %%
marvel_df.loc['Vision', 'first_appearance'] = 1964

marvel_df
# Out:
#                     name  gender  first_appearance
# 0             Spider-Man    male            1962.0
# 1        Captain America    male            1941.0
# 2              Wolverine    male            1974.0
# 3               Iron Man    male            1963.0
# 4                   Thor    male            1963.0
# 5                  Thing    male            1961.0
# 6       Mister Fantastic    male            1961.0
# 7                   Hulk    male            1962.0
# 8                  Beast    male            1963.0
# 9        Invisible Woman  female            1961.0
# 10                 Storm  female            1975.0
# 11                 Namor    male            1939.0
# 12               Hawkeye    male            1964.0
# 13             Daredevil    male            1964.0
# 14        Doctor Strange    male            1963.0
# 15              Hank Pym    male            1962.0
# 16         Scarlet Witch  female            1964.0
# ...

# %%
mask = marvel_df['gender'] == 'female'

mask
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9          True
# 10         True
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16         True
# 17         True
# 18         True
# 19        False
# Vision    False
# Name: gender, dtype: bool

# %%
mask = marvel_df['gender'] == 'male'

marvel_df[mask]
# Out:
#                 name gender  first_appearance
# 0         Spider-Man   male            1962.0
# 1    Captain America   male            1941.0
# 2          Wolverine   male            1974.0
# 3           Iron Man   male            1963.0
# 4               Thor   male            1963.0
# 5              Thing   male            1961.0
# 6   Mister Fantastic   male            1961.0
# 7               Hulk   male            1962.0
# 8              Beast   male            1963.0
# 11             Namor   male            1939.0
# 12           Hawkeye   male            1964.0
# 13         Daredevil   male            1964.0
# 14    Doctor Strange   male            1963.0
# 15          Hank Pym   male            1962.0
# 19            Vision   male            1968.0

# %%
mask = marvel_df['first_appearance'] > 1970

marvel_df[mask]
# Out:
#          name  gender  first_appearance
# 2   Wolverine    male            1974.0
# 10      Storm  female            1975.0

# %%
df = pd.read_csv('/content/btc-market-price.csv')
df.head()
# Out:
#    2017-04-02 00:00:00  1099.169125
# 0  2017-04-03 00:00:00  1141.813000
# 1  2017-04-04 00:00:00  1141.600363
# 2  2017-04-05 00:00:00  1133.079314
# 3  2017-04-06 00:00:00  1196.307937
# 4  2017-04-07 00:00:00  1190.454250

# %%
df = pd.read_csv('/content/btc-market-price.csv', header=None)
df.head()
# Out:
#                      0            1
# 0  2017-04-02 00:00:00  1099.169125
# 1  2017-04-03 00:00:00  1141.813000
# 2  2017-04-04 00:00:00  1141.600363
# 3  2017-04-05 00:00:00  1133.079314
# 4  2017-04-06 00:00:00  1196.307937

# %%
df.columns=["TimeStamp","Price"]
df.head()
# Out:
#              TimeStamp        Price
# 0  2017-04-02 00:00:00  1099.169125
# 1  2017-04-03 00:00:00  1141.813000
# 2  2017-04-04 00:00:00  1141.600363
# 3  2017-04-05 00:00:00  1133.079314
# 4  2017-04-06 00:00:00  1196.307937

# %%
df.tail(3)
# Out:
#                TimeStamp        Price
# 362  2018-03-30 00:00:00  6882.531667
# 363  2018-03-31 00:00:00  6935.480000
# 364  2018-04-01 00:00:00  6794.105000

# %%
df.plot()
# Out:
# <Axes: >

# %%
pd.to_datetime(df['TimeStamp']).head(10)
# Out:
# 0   2017-04-02
# 1   2017-04-03
# 2   2017-04-04
# 3   2017-04-05
# 4   2017-04-06
# 5   2017-04-07
# 6   2017-04-08
# 7   2017-04-09
# 8   2017-04-10
# 9   2017-04-11
# Name: TimeStamp, dtype: datetime64[ns]
